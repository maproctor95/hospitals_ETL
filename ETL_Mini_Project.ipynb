# %%
# Import dependencies
import pandas as pd
import numpy as np
pd.set_option('max_colwidth', 400)

# %% [markdown]
# ### Extract the Hospital.csv Data

# %%
# Read the data into a Pandas DataFrame
Hospital_info_df = pd.read_csv('Data/Hospitals_data_world.csv')
Hospital_info_df.head()
# Out:
#            X          Y   FID        ID  \
# 0 -88.454440  44.187135  6001  14954956
# 1 -88.453385  44.187490  6002  15054956
# 2 -88.595218  44.027747  6003  15154904
# 3 -88.601045  44.012421  6004  15254904
# 4 -90.178742  44.677262  6005  15354449
#
#                                       NAME                ADDRESS  \
# 0  CHILDRENS HSPTL OF WISCONSIN FOX VALLEY          130 SECOND ST
# 1                      THEDA CLARK MED CTR             130 2ND ST
# 2                   AURORA MED CTR OSHKOSH  855 N WESTHAVEN DRIVE
# 3                 MERCY MED CTR OF OSHKOSH       500 S OAKWOOD RD
# 4          MINISTRY SAINT JOSEPHS HOSPITAL      611 ST JOSEPH AVE
#
#         ADDRESS2        CITY STATE    ZIP  ...  \
# 0  Not Available      Neenah    WI  54956  ...
# 1  Not Available      Neenah    WI  54956  ...
# 2  Not Available     Oshkosh    WI  54904  ...
# 3  Not Available     Oshkosh    WI  54904  ...
# 4  Not Available  Marshfield    WI  54449  ...
#
# ...

# %%
# Rename the name columns.
Hospital_info_df = Hospital_info_df.rename(columns={'NAME': 'Hospital'})
Hospital_info_df.head()
# Out:
#            X          Y   FID        ID  \
# 0 -88.454440  44.187135  6001  14954956
# 1 -88.453385  44.187490  6002  15054956
# 2 -88.595218  44.027747  6003  15154904
# 3 -88.601045  44.012421  6004  15254904
# 4 -90.178742  44.677262  6005  15354449
#
#                                   Hospital                ADDRESS  \
# 0  CHILDRENS HSPTL OF WISCONSIN FOX VALLEY          130 SECOND ST
# 1                      THEDA CLARK MED CTR             130 2ND ST
# 2                   AURORA MED CTR OSHKOSH  855 N WESTHAVEN DRIVE
# 3                 MERCY MED CTR OF OSHKOSH       500 S OAKWOOD RD
# 4          MINISTRY SAINT JOSEPHS HOSPITAL      611 ST JOSEPH AVE
#
#         ADDRESS2        CITY STATE    ZIP  ...  \
# 0  Not Available      Neenah    WI  54956  ...
# 1  Not Available      Neenah    WI  54956  ...
# 2  Not Available     Oshkosh    WI  54904  ...
# 3  Not Available     Oshkosh    WI  54904  ...
# 4  Not Available  Marshfield    WI  54449  ...
#
# ...

# %%
# Get a brief summary 
Hospital_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6470 entries, 0 to 6469
# Data columns (total 36 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   X           6470 non-null   float64
#  1   Y           6470 non-null   float64
#  2   FID         6470 non-null   int64
#  3   ID          6470 non-null   int64
#  4   Hospital    6470 non-null   object
#  5   ADDRESS     6470 non-null   object
#  6   ADDRESS2    6470 non-null   object
#  7   CITY        6470 non-null   object
#  8   STATE       6470 non-null   object
#  9   ZIP         6470 non-null   int64
#  10  ZIP4        6470 non-null   object
#  11  TELEPHONE   6470 non-null   object
#  12  TYPE        6470 non-null   object
#  13  STATUS      6470 non-null   object
#  14  POPULATION  6470 non-null   int64
#  15  COUNTY      6470 non-null   object
#  16  COUNTYFIPS  6470 non-null   int64
#  17  COUNTRY     6470 non-null   object
#  18  LATITUDE    6470 non-null   float64
# ...

# %%
# Get the columns.
Hospital_info_df.columns
# Out:
# Index(['X', 'Y', 'FID', 'ID', 'Hospital', 'ADDRESS', 'ADDRESS2', 'CITY',
#        'STATE', 'ZIP', 'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION',
#        'COUNTY', 'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE',
#        'NAICS_CODE', 'NAICS_DESC', 'SOURCE', 'SOURCE_DAT', 'VAL_METHOD',
#        'VAL_DATE', 'WEBSITE', 'STATE_ID', 'ALT_NAME', 'ST_FIPS', 'OWNER',
#        'TTL_STAFF', 'BEDS', 'TRAUMA', 'HELIPAD', 'DATE_CREAT'],
#       dtype='object')

# %% [markdown]
# ### Extract the children_hospitals.csv data

# %%
# Read the data into a Pandas DataFrame
children_hospital_info_df = pd.read_csv('Data/childrens_hospitals.csv')
children_hospital_info_df.head()
# Out:
#                                        Hospital Alternative Name  \
# 0                 Children's Hospital of Nevada              NaN
# 1                   Phoenix Children's Hospital              NaN
# 2  AnMed Health Women's and Children's Hospital              NaN
# 3             Jeff Gordon's Children's Hospital              NaN
# 4                    Levine Children's Hospital              NaN
#
#                                     Address             Address 1 Address 2  \
# 0          800 Hope Pl, Las Vegas, NV 89106           800 Hope Pl       NaN
# 1     1919 E. Thomas Rd., Phoenix, AZ 85016    1919 E. Thomas Rd.       NaN
# 2  2000 E Greenville St, Anderson, SC 29621  2000 E Greenville St       NaN
# 3        920 Church St N, Concord, NC 28025       920 Church St N       NaN
# 4     1000 Blythe Blvd, Charlotte, NC 28203      1000 Blythe Blvd       NaN
#
#          City State    Zip  \
# 0   Las Vegas    LA  89106
# 1     Phoenix    AZ  85016
# 2    Anderson    SC  29621
# ...

# %%
# Get a brief summary 
children_hospital_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Hospital                223 non-null    object
#  1   Alternative Name        2 non-null      object
#  2   Address                 217 non-null    object
#  3   Address 1               217 non-null    object
#  4   Address 2               3 non-null      object
#  5   City                    217 non-null    object
#  6   State                   217 non-null    object
#  7   Zip                     215 non-null    object
#  8   Hospital Website        221 non-null    object
#  9   Latitude                217 non-null    float64
#  10  Longitude               217 non-null    float64
#  11  Caring System           1 non-null      object
#  12  Funding                 1 non-null      object
#  13  Type                    1 non-null      object
# ...

# %%
# Get the columns.
children_hospital_info_df.columns
# Out:
# Index(['Hospital', 'Alternative Name', 'Address', 'Address 1', 'Address 2',
#        'City', 'State', 'Zip', 'Hospital Website', 'Latitude', 'Longitude',
#        'Caring System', 'Funding', 'Type', 'Affiliation', 'Beds',
#        'Regular Beds', 'NICU Beds', 'Opened', 'Pediatric Trauma Level',
#        'NICU Level', 'Ranked Specialties', 'Wikipedia Source',
#        'Magnet Designation'],
#       dtype='object')

# %%
children_hospital_info_df[["childrens_hospital"]] = 'TRUE'

# %%
children_hospital_info_df.head()
# Out:
#                                        Hospital Alternative Name  \
# 0                 Children's Hospital of Nevada              NaN
# 1                   Phoenix Children's Hospital              NaN
# 2  AnMed Health Women's and Children's Hospital              NaN
# 3             Jeff Gordon's Children's Hospital              NaN
# 4                    Levine Children's Hospital              NaN
#
#                                     Address             Address 1 Address 2  \
# 0          800 Hope Pl, Las Vegas, NV 89106           800 Hope Pl       NaN
# 1     1919 E. Thomas Rd., Phoenix, AZ 85016    1919 E. Thomas Rd.       NaN
# 2  2000 E Greenville St, Anderson, SC 29621  2000 E Greenville St       NaN
# 3        920 Church St N, Concord, NC 28025       920 Church St N       NaN
# 4     1000 Blythe Blvd, Charlotte, NC 28203      1000 Blythe Blvd       NaN
#
#          City State    Zip  \
# 0   Las Vegas    LA  89106
# 1     Phoenix    AZ  85016
# 2    Anderson    SC  29621
# ...

# %% [markdown]
# ### Merge Data Frames together

# %%
Hospitals_merged_df = Hospital_info_df.merge(children_hospital_info_df, on='Hospital', how='left')

Hospitals_merged_df.tail()
# Out:
#               X          Y   FID       ID                          Hospital  \
# 6477 -75.654380  43.077706  5996  5613037        Oneida Healthcare Hospital
# 6478 -77.617992  43.112998  5997  5714620         Monroe Community Hospital
# 6479 -74.187099  42.958917  5998  5812010  Amsterdam Memorial Health Center
# 6480 -74.216064  42.954417  5999  5912010             St. Mary's Healthcare
# 6481 -73.622373  40.870946  6000  6011542                Glen Cove Hospital
#
#                              ADDRESS       ADDRESS2         CITY STATE    ZIP  \
# 6477  1072 Northside Shopping Center  Not Available  Chittenango    NY  13037
# 6478              435 E Henrietta Rd  Not Available    Rochester    NY  14620
# 6479           4988 State Highway 30  Not Available    Amsterdam    NY  12010
# 6480                427 Guy Park Ave  Not Available    Amsterdam    NY  12010
# 6481                 1 School Street  Not Available    Glen Cove    NY  11542
#
# ...

# %%
# Get the columns.
Hospitals_merged_df.columns
# Out:
# Index(['X', 'Y', 'FID', 'ID', 'Hospital', 'ADDRESS', 'ADDRESS2', 'CITY',
#        'STATE', 'ZIP', 'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION',
#        'COUNTY', 'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE',
#        'NAICS_CODE', 'NAICS_DESC', 'SOURCE', 'SOURCE_DAT', 'VAL_METHOD',
#        'VAL_DATE', 'WEBSITE', 'STATE_ID', 'ALT_NAME', 'ST_FIPS', 'OWNER',
#        'TTL_STAFF', 'BEDS', 'TRAUMA', 'HELIPAD', 'DATE_CREAT',
#        'Alternative Name', 'Address', 'Address 1', 'Address 2', 'City',
#        'State', 'Zip', 'Hospital Website', 'Latitude', 'Longitude',
#        'Caring System', 'Funding', 'Type', 'Affiliation', 'Beds',
#        'Regular Beds', 'NICU Beds', 'Opened', 'Pediatric Trauma Level',
#        'NICU Level', 'Ranked Specialties', 'Wikipedia Source',
#        'Magnet Designation', 'childrens_hospital'],
#       dtype='object')

# %%
#Delete the unwanted columns
Hospitals_merged_df = Hospitals_merged_df.drop(columns={'X', 'Y', 'ID',
       'ZIP4', 
       'COUNTYFIPS', 
       'NAICS_CODE', 'NAICS_DESC', 'SOURCE', 'SOURCE_DAT', 'VAL_METHOD',
       'VAL_DATE', 'ALT_NAME', 'ST_FIPS', 'OWNER',
       'TTL_STAFF', 'DATE_CREAT', 'Beds',
       'Alternative Name', 'Address', 'Address 1', 'Address 2', 'City',
       'State', 'Zip', 'Hospital Website', 'Latitude', 'Longitude',
         'Type', 'Wikipedia Source',
       'Magnet Designation'})
Hospitals_merged_df.head()
# Out:
#     FID                                 Hospital                ADDRESS  \
# 0  6001  CHILDRENS HSPTL OF WISCONSIN FOX VALLEY          130 SECOND ST
# 1  6002                      THEDA CLARK MED CTR             130 2ND ST
# 2  6003                   AURORA MED CTR OSHKOSH  855 N WESTHAVEN DRIVE
# 3  6004                 MERCY MED CTR OF OSHKOSH       500 S OAKWOOD RD
# 4  6005          MINISTRY SAINT JOSEPHS HOSPITAL      611 ST JOSEPH AVE
#
#         ADDRESS2        CITY STATE    ZIP       TELEPHONE  \
# 0  Not Available      Neenah    WI  54956  (920) 969-7902
# 1  Not Available      Neenah    WI  54956  (920) 729-3100
# 2  Not Available     Oshkosh    WI  54904  (920) 456-6000
# 3  Not Available     Oshkosh    WI  54904  (920) 223-2000
# 4  Not Available  Marshfield    WI  54449  (715) 387-7850
#
#                           TYPE STATUS  ...  Caring System Funding Affiliation  \
# 0  General Acute Care Hospital   Open  ...            NaN     NaN         NaN
# ...

# %%
Hospitals_merged_df.columns
# Out:
# Index(['FID', 'Hospital', 'ADDRESS', 'ADDRESS2', 'CITY', 'STATE', 'ZIP',
#        'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY', 'COUNTRY',
#        'LATITUDE', 'LONGITUDE', 'WEBSITE', 'STATE_ID', 'BEDS', 'TRAUMA',
#        'HELIPAD', 'Caring System', 'Funding', 'Affiliation', 'Regular Beds',
#        'NICU Beds', 'Opened', 'Pediatric Trauma Level', 'NICU Level',
#        'Ranked Specialties', 'childrens_hospital'],
#       dtype='object')

# %%
# Rename the columns.
Hospitals_merged_df = Hospitals_merged_df.rename(columns={'Hospital': 'hospital_name', 'ADDRESS': 'address', 'CITY': 'city', 'STATE': 'state', 'ZIP': 'zip', 'TYPE': 'type', 'STATUS': 'status',
       'POPULATION': 'population', 'COUNTY': 'county', 'COUNTRY': 'country', 'LATITUDE': 'latitude', 'LONGITUDE': 'longitude', 'WEBSITE': 'website',
       'BEDS': 'beds', 'TRAUMA': 'trauma', 'HELIPAD': 'helipad', 'ADDRESS2': 'address2', 'TELEPHONE':'telephone', 'FID': 'fid', 'STATEID': 'stateid'})
Hospitals_merged_df.head()
# Out:
#     fid                            hospital_name                address  \
# 0  6001  CHILDRENS HSPTL OF WISCONSIN FOX VALLEY          130 SECOND ST
# 1  6002                      THEDA CLARK MED CTR             130 2ND ST
# 2  6003                   AURORA MED CTR OSHKOSH  855 N WESTHAVEN DRIVE
# 3  6004                 MERCY MED CTR OF OSHKOSH       500 S OAKWOOD RD
# 4  6005          MINISTRY SAINT JOSEPHS HOSPITAL      611 ST JOSEPH AVE
#
#         address2        city state    zip       telephone  \
# 0  Not Available      Neenah    WI  54956  (920) 969-7902
# 1  Not Available      Neenah    WI  54956  (920) 729-3100
# 2  Not Available     Oshkosh    WI  54904  (920) 456-6000
# 3  Not Available     Oshkosh    WI  54904  (920) 223-2000
# 4  Not Available  Marshfield    WI  54449  (715) 387-7850
#
#                           type status  ...  Caring System Funding Affiliation  \
# 0  General Acute Care Hospital   Open  ...            NaN     NaN         NaN
# ...

# %%
# Check the datatypes
Hospitals_merged_df.dtypes
# Out:
# fid                         int64
# hospital_name              object
# address                    object
# address2                   object
# city                       object
# state                      object
# zip                         int64
# telephone                  object
# type                       object
# status                     object
# population                  int64
# county                     object
# country                    object
# latitude                  float64
# longitude                 float64
# website                    object
# STATE_ID                   object
# beds                        int64
# trauma                     object
# helipad                    object
# Caring System              object
# Funding                    object
# Affiliation                object
# Regular Beds              float64
# NICU Beds                 float64
# Opened                    float64
# Pediatric Trauma Level     object
# ...

# %%
# Export the DataFrame as a CSV file. 
Hospitals_merged_df.to_csv("Data/Hospitals_merged.csv", index=False)

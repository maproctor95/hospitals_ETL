# %%
# Import dependencies
import pandas as pd
import numpy as np
pd.set_option('max_colwidth', 400)

# %% [markdown]
# ### Extract the Hospital.csv Data

# %%
# Read the data into a Pandas DataFrame
Hospital_info_df = pd.read_csv('Data/Hospitals.csv')
Hospital_info_df.head()
# Out:
#            X          Y  OBJECTID         ID  \
# 0 -94.945477  29.747620      8497   76777520
# 1 -82.881843  40.027143      8498  129043230
# 2 -84.168027  39.774242      8499  130045404
# 3 -80.632972  41.005169      8500  128844512
# 4 -84.199398  39.747740      8501  129845417
#
#                                                       NAME  \
# 0  HOUSTON METHODIST SAN JACINTO HOSPITAL ALEXANDER CAMPUS
# 1                                    WOODS AT PARKSIDE,THE
# 2                               DAYTON CHILDREN'S HOSPITAL
# 3                        VIBRA HOSPITAL OF MAHONING VALLEY
# 4                   HAVEN BEHAVIORAL SENIOR CARE OF DAYTON
#
#                           ADDRESS      CITY STATE    ZIP           ZIP4  ...  \
# 0          1700 JAMES BOWIE DRIVE   BAYTOWN    TX  77520  NOT AVAILABLE  ...
# 1          349 OLDE RIDENOUR ROAD  COLUMBUS    OH  43230  NOT AVAILABLE  ...
# 2             ONE CHILDRENS PLAZA    DAYTON    OH  45404  NOT AVAILABLE  ...
# ...

# %%
# Rename the name columns.
Hospital_info_df = Hospital_info_df.rename(columns={'NAME': 'Hospital'})
Hospital_info_df.head()
# Out:
#            X          Y  OBJECTID         ID  \
# 0 -94.945477  29.747620      8497   76777520
# 1 -82.881843  40.027143      8498  129043230
# 2 -84.168027  39.774242      8499  130045404
# 3 -80.632972  41.005169      8500  128844512
# 4 -84.199398  39.747740      8501  129845417
#
#                                                   Hospital  \
# 0  HOUSTON METHODIST SAN JACINTO HOSPITAL ALEXANDER CAMPUS
# 1                                    WOODS AT PARKSIDE,THE
# 2                               DAYTON CHILDREN'S HOSPITAL
# 3                        VIBRA HOSPITAL OF MAHONING VALLEY
# 4                   HAVEN BEHAVIORAL SENIOR CARE OF DAYTON
#
#                           ADDRESS      CITY STATE    ZIP           ZIP4  ...  \
# 0          1700 JAMES BOWIE DRIVE   BAYTOWN    TX  77520  NOT AVAILABLE  ...
# 1          349 OLDE RIDENOUR ROAD  COLUMBUS    OH  43230  NOT AVAILABLE  ...
# 2             ONE CHILDRENS PLAZA    DAYTON    OH  45404  NOT AVAILABLE  ...
# ...

# %%
# Get a brief summary 
Hospital_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7570 entries, 0 to 7569
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   X           7570 non-null   float64
#  1   Y           7570 non-null   float64
#  2   OBJECTID    7570 non-null   int64
#  3   ID          7570 non-null   int64
#  4   Hospital    7570 non-null   object
#  5   ADDRESS     7570 non-null   object
#  6   CITY        7570 non-null   object
#  7   STATE       7570 non-null   object
#  8   ZIP         7570 non-null   int64
#  9   ZIP4        7570 non-null   object
#  10  TELEPHONE   7570 non-null   object
#  11  TYPE        7570 non-null   object
#  12  STATUS      7570 non-null   object
#  13  POPULATION  7570 non-null   int64
#  14  COUNTY      7570 non-null   object
#  15  COUNTYFIPS  7570 non-null   object
#  16  COUNTRY     7570 non-null   object
#  17  LATITUDE    7570 non-null   float64
#  18  LONGITUDE   7570 non-null   float64
# ...

# %%
# Get the columns.
Hospital_info_df.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'ID', 'Hospital', 'ADDRESS', 'CITY', 'STATE',
#        'ZIP', 'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY',
#        'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE',
#        'NAICS_DESC', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE',
#        'WEBSITE', 'STATE_ID', 'ALT_NAME', 'ST_FIPS', 'OWNER', 'TTL_STAFF',
#        'BEDS', 'TRAUMA', 'HELIPAD'],
#       dtype='object')

# %% [markdown]
# ### Extract the children_hospitals.csv data

# %%
# Read the data into a Pandas DataFrame
children_hospital_info_df = pd.read_csv('Data/childrens_hospitals.csv')
children_hospital_info_df.head()
# Out:
#                                        Hospital Alternative Name  \
# 0                 Children's Hospital of Nevada              NaN
# 1                   Phoenix Children's Hospital              NaN
# 2  AnMed Health Women's and Children's Hospital              NaN
# 3             Jeff Gordon's Children's Hospital              NaN
# 4                    Levine Children's Hospital              NaN
#
#                                     Address             Address 1 Address 2  \
# 0          800 Hope Pl, Las Vegas, NV 89106           800 Hope Pl       NaN
# 1     1919 E. Thomas Rd., Phoenix, AZ 85016    1919 E. Thomas Rd.       NaN
# 2  2000 E Greenville St, Anderson, SC 29621  2000 E Greenville St       NaN
# 3        920 Church St N, Concord, NC 28025       920 Church St N       NaN
# 4     1000 Blythe Blvd, Charlotte, NC 28203      1000 Blythe Blvd       NaN
#
#          City State    Zip  \
# 0   Las Vegas    LA  89106
# 1     Phoenix    AZ  85016
# 2    Anderson    SC  29621
# ...

# %%
# Get a brief summary 
children_hospital_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Hospital                223 non-null    object
#  1   Alternative Name        2 non-null      object
#  2   Address                 217 non-null    object
#  3   Address 1               217 non-null    object
#  4   Address 2               3 non-null      object
#  5   City                    217 non-null    object
#  6   State                   217 non-null    object
#  7   Zip                     215 non-null    object
#  8   Hospital Website        221 non-null    object
#  9   Latitude                217 non-null    float64
#  10  Longitude               217 non-null    float64
#  11  Caring System           1 non-null      object
#  12  Funding                 1 non-null      object
#  13  Type                    1 non-null      object
# ...

# %%
# Get the columns.
children_hospital_info_df.columns
# Out:
# Index(['Hospital', 'Alternative Name', 'Address', 'Address 1', 'Address 2',
#        'City', 'State', 'Zip', 'Hospital Website', 'Latitude', 'Longitude',
#        'Caring System', 'Funding', 'Type', 'Affiliation', 'Beds',
#        'Regular Beds', 'NICU Beds', 'Opened', 'Pediatric Trauma Level',
#        'NICU Level', 'Ranked Specialties', 'Wikipedia Source',
#        'Magnet Designation'],
#       dtype='object')

# %%
children_hospital_info_df[["childrens hospital"]] = 'yes'

# %%
children_hospital_info_df.head()
# Out:
#                                        Hospital Alternative Name  \
# 0                 Children's Hospital of Nevada              NaN
# 1                   Phoenix Children's Hospital              NaN
# 2  AnMed Health Women's and Children's Hospital              NaN
# 3             Jeff Gordon's Children's Hospital              NaN
# 4                    Levine Children's Hospital              NaN
#
#                                     Address             Address 1 Address 2  \
# 0          800 Hope Pl, Las Vegas, NV 89106           800 Hope Pl       NaN
# 1     1919 E. Thomas Rd., Phoenix, AZ 85016    1919 E. Thomas Rd.       NaN
# 2  2000 E Greenville St, Anderson, SC 29621  2000 E Greenville St       NaN
# 3        920 Church St N, Concord, NC 28025       920 Church St N       NaN
# 4     1000 Blythe Blvd, Charlotte, NC 28203      1000 Blythe Blvd       NaN
#
#          City State    Zip  \
# 0   Las Vegas    LA  89106
# 1     Phoenix    AZ  85016
# 2    Anderson    SC  29621
# ...

# %% [markdown]
# ### Merge Data Frames together

# %%
Hospitals_merged_df = Hospital_info_df.merge(children_hospital_info_df, on='Hospital', how='left')

Hospitals_merged_df.tail()
# Out:
#               X          Y  OBJECTID         ID  \
# 7565 -80.701221  40.372434      8492  128243953
# 7566 -81.336345  40.401257      8493  127744621
# 7567 -84.294586  39.331523      8494  128345040
# 7568 -97.283341  29.112615      8495   13879022
# 7569 -95.359806  29.711039      8496   76677004
#
#                                          Hospital  \
# 7565                           LIFE LINE HOSPITAL
# 7566                        TEN LAKES CENTER, LLC
# 7567                       LINDNER CENTER OF HOPE
# 7568                     CUERO COMMUNITY HOSPITAL
# 7569  HARRIS HEALTH SYSTEM QUENTIN MEASE HOSPITAL
#
#                                ADDRESS          CITY STATE    ZIP  \
# 7565                 200 SCHOOL STREET  WINTERSVILLE    OH  43953
# 7566  819 NORTH FIRST STREET,3RD FLOOR      DENNISON    OH  44621
# 7567         4075 OLD WESTERN ROW ROAD         MASON    OH  45040
# 7568       2550 NORTH ESPLANADE STREET         CUERO    TX  79022
# ...

# %%
# Get the columns.
Hospitals_merged_df.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'ID', 'Hospital', 'ADDRESS', 'CITY', 'STATE',
#        'ZIP', 'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY',
#        'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE',
#        'NAICS_DESC', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE',
#        'WEBSITE', 'STATE_ID', 'ALT_NAME', 'ST_FIPS', 'OWNER', 'TTL_STAFF',
#        'BEDS', 'TRAUMA', 'HELIPAD', 'Alternative Name', 'Address', 'Address 1',
#        'Address 2', 'City', 'State', 'Zip', 'Hospital Website', 'Latitude',
#        'Longitude', 'Caring System', 'Funding', 'Type', 'Affiliation', 'Beds',
#        'Regular Beds', 'NICU Beds', 'Opened', 'Pediatric Trauma Level',
#        'NICU Level', 'Ranked Specialties', 'Wikipedia Source',
#        'Magnet Designation', 'childrens hospital'],
#       dtype='object')

# %%
#Delete the unwanted columns
Hospitals_merged_df = Hospitals_merged_df.drop(columns={'X', 'Y', 'OBJECTID', 'ID', 'ZIP4', 'TELEPHONE',
       'COUNTYFIPS', 'NAICS_CODE',
       'NAICS_DESC', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE', 'STATE_ID', 'ALT_NAME', 'ST_FIPS', 'OWNER', 'TTL_STAFF',
        'Alternative Name', 'Address', 'Address 1',
       'Address 2', 'City', 'State', 'Zip', 'Hospital Website', 'Latitude',
       'Longitude', 'Type', 'Affiliation', 'Opened',
        'Ranked Specialties', 'Wikipedia Source',
       'Magnet Designation', 'Caring System', 'Funding', 'Type', 'Affiliation', 'Beds',
       'Regular Beds', 'NICU Beds', 'Opened', 'Pediatric Trauma Level',
       'NICU Level', 'Ranked Specialties', 'Wikipedia Source',
       'Magnet Designation'})
Hospitals_merged_df.head()
# Out:
#                                                   Hospital  \
# 0  HOUSTON METHODIST SAN JACINTO HOSPITAL ALEXANDER CAMPUS
# 1                                    WOODS AT PARKSIDE,THE
# 2                               DAYTON CHILDREN'S HOSPITAL
# 3                        VIBRA HOSPITAL OF MAHONING VALLEY
# 4                   HAVEN BEHAVIORAL SENIOR CARE OF DAYTON
#
#                           ADDRESS      CITY STATE    ZIP                TYPE  \
# 0          1700 JAMES BOWIE DRIVE   BAYTOWN    TX  77520  GENERAL ACUTE CARE
# 1          349 OLDE RIDENOUR ROAD  COLUMBUS    OH  43230             SPECIAL
# 2             ONE CHILDRENS PLAZA    DAYTON    OH  45404            CHILDREN
# 3               8049 SOUTH AVENUE  BOARDMAN    OH  44512      LONG TERM CARE
# 4  ONE ELIZABETH PLACE,E3 SUITE A    DAYTON    OH  45417         PSYCHIATRIC
#
#   STATUS  POPULATION      COUNTY COUNTRY   LATITUDE  LONGITUDE  \
# 0   OPEN         182      HARRIS     USA  29.747620 -94.945477
# ...

# %%
Hospitals_merged_df.columns
# Out:
# Index(['Hospital', 'ADDRESS', 'CITY', 'STATE', 'ZIP', 'TYPE', 'STATUS',
#        'POPULATION', 'COUNTY', 'COUNTRY', 'LATITUDE', 'LONGITUDE', 'WEBSITE',
#        'BEDS', 'TRAUMA', 'HELIPAD', 'childrens hospital'],
#       dtype='object')

# %%
# Rename the columns.
Hospitals_merged_df = Hospitals_merged_df.rename(columns={'Hospital': 'hospital_name', 'ADDRESS': 'address', 'CITY': 'city', 'STATE': 'state', 'ZIP': 'zip', 'TYPE': 'type', 'STATUS': 'status',
       'POPULATION': 'population', 'COUNTY': 'county', 'COUNTRY': 'country', 'LATITUDE': 'latitude', 'LONGITUDE': 'longitude', 'WEBSITE': 'website',
       'BEDS': 'beds', 'TRAUMA': 'trauma', 'HELIPAD': 'helipad'})
Hospitals_merged_df.head()
# Out:
#                                              hospital_name  \
# 0  HOUSTON METHODIST SAN JACINTO HOSPITAL ALEXANDER CAMPUS
# 1                                    WOODS AT PARKSIDE,THE
# 2                               DAYTON CHILDREN'S HOSPITAL
# 3                        VIBRA HOSPITAL OF MAHONING VALLEY
# 4                   HAVEN BEHAVIORAL SENIOR CARE OF DAYTON
#
#                           address      city state    zip                type  \
# 0          1700 JAMES BOWIE DRIVE   BAYTOWN    TX  77520  GENERAL ACUTE CARE
# 1          349 OLDE RIDENOUR ROAD  COLUMBUS    OH  43230             SPECIAL
# 2             ONE CHILDRENS PLAZA    DAYTON    OH  45404            CHILDREN
# 3               8049 SOUTH AVENUE  BOARDMAN    OH  44512      LONG TERM CARE
# 4  ONE ELIZABETH PLACE,E3 SUITE A    DAYTON    OH  45417         PSYCHIATRIC
#
#   status  population      county country   latitude  longitude  \
# 0   OPEN         182      HARRIS     USA  29.747620 -94.945477
# ...

# %%
Hospitals_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7570 entries, 0 to 7569
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   hospital_name       7570 non-null   object
#  1   address             7570 non-null   object
#  2   city                7570 non-null   object
#  3   state               7570 non-null   object
#  4   zip                 7570 non-null   int64
#  5   type                7570 non-null   object
#  6   status              7570 non-null   object
#  7   population          7570 non-null   int64
#  8   county              7570 non-null   object
#  9   country             7570 non-null   object
#  10  latitude            7570 non-null   float64
#  11  longitude           7570 non-null   float64
#  12  website             7570 non-null   object
#  13  beds                7569 non-null   float64
#  14  trauma              7569 non-null   object
# ...

# %%
# Convert the goal and pledged columns to a `float` data type.
Hospitals_merged_df[['hospital_name','address', 'city','state','type','status','county', 'country','website','trauma', 'helipad', 'childrens hospital'
]] = Hospitals_merged_df[['hospital_name','address', 'city','state','type','status','county', 'country','website','trauma', 'helipad', 'childrens hospital'
]].astype(str)
Hospitals_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7570 entries, 0 to 7569
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   hospital_name       7570 non-null   object
#  1   address             7570 non-null   object
#  2   city                7570 non-null   object
#  3   state               7570 non-null   object
#  4   zip                 7570 non-null   int64
#  5   type                7570 non-null   object
#  6   status              7570 non-null   object
#  7   population          7570 non-null   int64
#  8   county              7570 non-null   object
#  9   country             7570 non-null   object
#  10  latitude            7570 non-null   float64
#  11  longitude           7570 non-null   float64
#  12  website             7570 non-null   object
#  13  beds                7569 non-null   float64
#  14  trauma              7570 non-null   object
# ...

# %%
# Check the datatypes
Hospitals_merged_df.dtypes
# Out:
# hospital_name          object
# address                object
# city                   object
# state                  object
# zip                     int64
# type                   object
# status                 object
# population              int64
# county                 object
# country                object
# latitude              float64
# longitude             float64
# website                object
# beds                  float64
# trauma                 object
# helipad                object
# childrens hospital     object
# dtype: object

# %%
# Export the DataFrame as a CSV file. 
campaign_cleaned.to_csv("Resources/campaign.csv", index=False)

# %% [markdown]
# ### Extract the contacts.xlsx Data.

# %%
# Read the data into a Pandas DataFrame. Use the `header=2` parameter when reading in the data.
contact_info_df = pd.read_excel('Resources/contacts.xlsx', header=3)
contact_info_df.head()

# %% [markdown]
# ### Create the Contacts DataFrame
# ---
# **Create a Contacts DataFrame that has the following columns:**
# - A column named "contact_id"  that contains the unique number of the contact person.
# - A column named "first_name" that contains the first name of the contact person.
# - A column named "last_name" that contains the first name of the contact person.
# - A column named "email" that contains the email address of the contact person
#
# Then export the DataFrame as a `contacts.csv` CSV file.

# %% [markdown]
# ### Option 1: Use Pandas to create the contacts DataFrame.

# %%
# Iterate through the contact_info_df and convert each row to a dictionary.
import json
dict_values = []
for i, row in contact_info_df.iterrows():
    data = row['contact_info']
    converted_data = json.loads(data)
    row_values = [v for k, v in converted_data.items()]
    dict_values.append(row_values)


# Print out the list of values for each row.
print(dict_values)

# %%
# Create a contact_info DataFrame and add each list of values, i.e., each row 
# to the 'contact_id', 'name', 'email' columns.
contacts_df = pd.DataFrame(dict_values, columns=['contact_id', 'name', 'email'])
contacts_df.head()

# %%
# Check the datatypes.
contacts_df.info()

# %%
# Create a "first"name" and "last_name" column with the first and last names from the "name" column. 
contacts_df[["first_name","last_name"]] = contacts_df["name"].str.split(' ', n=1, expand=True)

# Drop the contact_name column
contacts_df_clean = contacts_df.drop(['name'], axis=1)
contacts_df_clean.head()

# %%
# Reorder the columns
contacts_df_clean = contacts_df_clean[['contact_id','first_name', 'last_name', 'email']]
contacts_df_clean.head()

# %%
# Check the datatypes one more time before exporting as CSV file.
contacts_df_clean.info()

# %%
# Export the DataFrame as a CSV file. 
contacts_df_clean.to_csv("Resources/contacts.csv", encoding='utf8', index=False)

# %% [markdown]
# ### Option 2: Use regex to create the contacts DataFrame.

# %%
contact_info_df_copy = contact_info_df.copy()
contact_info_df_copy.head()

# %%
# Extract the four-digit contact ID number.
contact_info_df_copy['contact_id'] = contact_info_df_copy['contact_info'].str.extract(r'(\d{4})')
contact_info_df_copy.head()

# %%
# Check the datatypes.
contact_info_df_copy.info()

# %%
# Convert the "contact_id" column to an int64 data type.
contact_info_df_copy['contact_id'] = pd.to_numeric(contact_info_df_copy['contact_id'])
contact_info_df_copy.info()

# %%
# Extract the name of the contact and add it to a new column.
contact_info_df_copy['name'] = contact_info_df_copy['contact_info'].str.extract(r'([^nameil"\s][A-Za-z]+\s+[A-Za-z]+)')
contact_info_df_copy.head()

# %%
# Extract the email from the contacts and add the values to a new column.
contact_info_df_copy['email'] = contact_info_df_copy['contact_info'].str.extract(r'"(\S+@\S+)"}')
contact_info_df_copy.head()

# %%
# Create a copy of the contact_info_df with the 'contact_id', 'name', 'email' columns.
contacts_df_copy2 = contact_info_df_copy[['contact_id', 'name', 'email']].copy()
contacts_df_copy2.head()

# %%
# Create a "first"name" and "last_name" column with the first and last names from the "name" column. 
contacts_df_copy2[["first_name","last_name"]] = contacts_df_copy2["name"].str.split(' ', n=1, expand=True)

# Drop the contact_name column
contacts_df_clean2 = contacts_df_copy2.drop(['name'], axis=1)
contacts_df_clean2.head()

# %%
# Reorder the columns
contacts_df_clean2 = contacts_df_clean2[['contact_id','first_name', 'last_name', 'email']]
contacts_df_clean2.head()

# %%
# Check the datatypes one more time before exporting as CSV file.
contacts_df_clean2.info()

# %%
# Export the DataFrame as a CSV file. 
contacts_df_clean.to_csv("Resources/contacts.csv", encoding='utf8', index=False)
